# %%
import numpy as np
from scipy import stats as stats

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd

import os

# %%
path = r'C:\Users\alpaula\Documents\Udemy - IA\Practical-statistics-for-data-scientists\practical-statistics-for-data-scientists\DataBase'

file = 'loans_income.csv'

filePath = os.path.join(path,file)

# %%
dfLoan = pd.read_csv(filePath)

data = dfLoan['x']

sns.histplot(x=data, bins=np.histogram_bin_edges(a=data, bins=28), kde=True)

plt.show()

# %%
x

# %%
shape, loc, scale = stats.lognorm.fit(data,floc=0)

x = np.linspace(data.min(), data.max(), 1000)

pdf = stats.lognorm.pdf(x, shape, loc, scale)

plt.hist(data, bins=28, density=True, alpha=0.5, color='blue', edgecolor='black')
plt.plot(x, pdf, 'r-', lw=2, label='Lognormal PDF')
plt.legend()
plt.show()

# %%
theta = np.var(dfLoan)/np.mean(dfLoan)

k = np.mean(dfLoan)/theta
# Out:
# C:\Users\alpaula\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %%
gamma = stats.weibull_max.rvs(10,50000,size=50000)

sns.histplot(x=gamma, bins=np.histogram_bin_edges(a=gamma, bins=28))
# Out:
# <Axes: ylabel='Count'>

# %%
data = stats.lognorm.rvs(s=.40, size=1000)

stats.probplot(x=dfLoan['x'], dist = stats.gamma.rvs(10,.1), plot=plt)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 3
#       1 data = stats.lognorm.rvs(s=.40, size=1000)
# ----> 3 stats.probplot(x=dfLoan['x'], dist = stats.gamma.rvs(10,.1), plot=plt)
#       5 plt.show()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\scipy\stats\_morestats.py:618, in probplot(x, sparams, dist, fit, plot, rvalue)
#     615 if not isinstance(sparams, tuple):
#     616     sparams = tuple(sparams)
# --> 618 osm = dist.ppf(osm_uniform, *sparams)
#     619 osr = sort(x)
#     620 if fit:
#     621     # perform a linear least squares fit.
#
# AttributeError: 'numpy.float64' object has no attribute 'ppf'

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
x = stats.loggamma.rvs(c=2.5, size=500, random_state=rng)
res = stats.probplot(x, dist=stats.loggamma, sparams=(2.5,), plot=ax)
ax.set_title("Probplot for loggamma dist with shape parameter 2.5")
