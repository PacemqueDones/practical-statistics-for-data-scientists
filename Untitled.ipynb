# %%
from numpy import *

import seaborn as sns
import matplotlib.pyplot as plt

import pandas as np

import os

# %%
path = r'C:\Users\ander\Documents\practical-statistics-for-data-scientists\DataBase'

file = 'loans_income.csv'

filePath = os.path.join(path,file)

# %%
dfLoan = np.read_csv(filePath)

sns.histplot(data=dfLoan,x='x', bins=histogram_bin_edges(a=dfLoan['x'], bins=28), kde=True)
# Out:
# <AxesSubplot:xlabel='x', ylabel='Count'>

# %%
gamma = random.gamma(9,0.5,size=50000)

sns.histplot(x=gamma, bins=histogram_bin_edges(a=gamma, bins=28))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
mean(dfLoan)
# Out:
# C:\Users\ander\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# x    68760.51844
# dtype: float64
